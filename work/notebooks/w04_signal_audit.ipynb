# %% [markdown]
# # ML-06 — Signal Audit: Do the Flags Hold?
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ankitpaul6201/Fly-rank-intern-01/blob/main/work/notebooks/w04_signal_audit.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Distributions
#
# *Look before deciding: distributions of your key fields. Note the heavy tails.*

# %%
import pandas as pd
import numpy as np
import os
data_path = "data/raw/content_refresh_anonymized.csv"
if not os.path.exists(data_path):
    data_path = "../../data/raw/content_refresh_anonymized.csv"
df = pd.read_csv(data_path)
print(f"Successfully loaded dataset: {len(df):,} rows")
# Out:
# Successfully loaded dataset: 30,000 rows

# %% [markdown]
# ## 2. Signal test #1 / #2 / #3 (verdict each)
#
# *Three safe signals, each with a mini-test and a verdict: CONFIRMED / OPPOSITE / MIXED / FALSE.*

# %%
import pandas as pd
import numpy as np
import os
data_path = "data/raw/content_refresh_anonymized.csv"
if not os.path.exists(data_path):
    data_path = "../../data/raw/content_refresh_anonymized.csv"
df = pd.read_csv(data_path)
print(f"Successfully loaded dataset: {len(df):,} rows")
# Out:
# Successfully loaded dataset: 30,000 rows

# %% [markdown]
# ## 3. The flag-linked test
#
# *Pick a signal one of FlyRank's real flags relies on. Does the data support the rule's assumption?*

# %%
import pandas as pd
import numpy as np
import os
data_path = "data/raw/content_refresh_anonymized.csv"
if not os.path.exists(data_path):
    data_path = "../../data/raw/content_refresh_anonymized.csv"
df = pd.read_csv(data_path)
print(f"Successfully loaded dataset: {len(df):,} rows")
# Out:
# Successfully loaded dataset: 30,000 rows

# %% [markdown]
# ## 4. What this means in practice
#
# *Two or three sentences: what a content team should take from this.*

# %%
import pandas as pd
import numpy as np
import os
data_path = "data/raw/content_refresh_anonymized.csv"
if not os.path.exists(data_path):
    data_path = "../../data/raw/content_refresh_anonymized.csv"
df = pd.read_csv(data_path)
print(f"Successfully loaded dataset: {len(df):,} rows")
# Out:
# Successfully loaded dataset: 30,000 rows

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
